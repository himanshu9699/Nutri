# %%
import pandas as pd
 
# read by default 1st sheet of an excel file
df = pd.read_csv('fruits_after_preprocessing.csv')
 
print(df)
# Out:
#                     Fruits  Calories  Carbohydrates  Protiens   Fats  Fibre
# 0                   Apples     49.05          11.83      0.35   0.10   1.97
# 1                 Apricots     51.60          11.96      1.50   0.42   2.15
# 2             Avocado Pear    190.00           1.90      1.90  19.50   3.40
# 3                   Banana     95.00          20.90      1.20   0.30   4.20
# 4             Blackberries     25.25           5.10      0.90   0.20   3.10
# 5            Blackcurrants     28.00           6.60      0.90   0.00   3.60
# 6              Blueberries     57.00          14.49      0.74   0.33   2.40
# 7                 Cherries     39.00           9.50      0.70   0.10   0.70
# 8              Clementines     47.00          12.02      0.85   0.15   1.70
# 9              Cranberries     15.00           3.40      0.40   0.10   3.00
# 10                 Damsons     30.60           7.70      0.50   0.00   1.40
# ...

# %%
if(df['Fruits']=="Apples"):
    print("hi")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <module>
# ----> 1 if(df['Fruits']=="Apples"):
#       2     print("hi")
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
ddf=df[df['Fruits'] == 'Apples']

# %%
a=ddf['Calories'].values

# %%
print("Calories",a[0])
# Out:
# Calories 49.05

# %%
from keras_preprocessing import image
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
model = tf.keras.models.load_model('mo.h5')
image_path="banana2.jpeg"
img = image.load_img(image_path, target_size=(224,224,3))
plt.imshow(img)
plt.show()
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
images = np.vstack([x])
pred = model.predict(images, batch_size=32)
label = np.argmax(pred, axis=1)
print("Predicted: "+class_names[np.argmax(pred)])
# Out:
# 1/1 [==============================] - 0s 293ms/step
# Predicted: banana

# %%
a=class_names[np.argmax(pred)]
a=a.capitalize()
fdf=df[df['Fruits'] == a]
print(class_names[np.argmax(pred)])
c=fdf.Calories
d=fdf.Carbohydrates
e=fdf.Protiens
f=fdf.Fats
g=fdf.Fibre
print("calories", c.values[0])
print("Carbohydrates",d.values[0])
print("Protiens",e.values[0])
print("Fats",e.values[0])
print("Fibre",f.values[0])
# Out:
# banana
# calories 95.0
# Carbohydrates 20.9
# Protiens 1.2
# Fats 1.2
# Fibre 0.3

# %%
a.capitalize()
# Out:
# 'Banana'

# %%
val_path="Dataset/validation"
train_path="Dataset/train"

train_dataset = tf.keras.preprocessing.image_dataset_from_directory(train_path,
                                                               seed=2509,
                                                               image_size=(224, 224),
                                                              batch_size=32)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
class_names = train_dataset.class_names

# %%
class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
class_names=['apple',
 'banana',
 'beetroot',
 'bell pepper',
 'cabbage',
 'capsicum',
 'carrot',
 'cauliflower',
 'chilli pepper',
 'corn',
 'cucumber',
 'eggplant',
 'garlic',
 'ginger',
 'grapes',
 'jalepeno',
 'kiwi',
 'lemon',
 'lettuce',
 'mango',
 'onion',
 'orange',
 'paprika',
 'pear',
 'peas',
 'pineapple',
 'pomegranate',
 'potato',
 'raddish',
 'soy beans',
 'spinach',
 'sweetcorn',
 'sweetpotato',
 'tomato',
 'turnip',
 'watermelon']

# %%
class_names
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
|
